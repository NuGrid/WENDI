# %%
from nugridpy import mesa as ms
ms.set_nugrid_path('/data/nugrid_apod2')
from nugridpy import nugridse as mp
mp.set_nugrid_path('/data/nugrid_apod2')
from matplotlib.pyplot import *
# %matplotlib nbagg

# %% [markdown]
# # in NuGrid_Set_explorer.ipynb

# %% [markdown]
# # Issue 1

# %% [markdown]
# ### Movie of abundance evolution in the C13-pocket
# We have found the location and cycle number range of a $^{13}C$-pocket in the stellar evolution analysis. Let's visualize the $^{13}C$-pocket with an animation:

# %%
pt=mp.se(mass=2,Z=0.02)
# Out:
# nugrid_path = /data/nugrid_apod2
# closest set is set1.2 (Z = 0.02)
# closest mass is 2.0
# Searching files, please wait.......
# Reading preprocessor files
# File search complete.

# %% [markdown]
# In the region just below the deepest penetration of 3rd dredge-up after a He-shell flash a thin layer of $^{13}{\rm C}$ was produced. There are also $\alpha$-particles in this layer that are being captured by the $^{13}{\rm C}$. Neutrons are released by the reaction $^{13}{\rm C}(\alpha,n)^{16}{\rm O}$ and successive captures of these neutrons by heavier seed nuclei such as iron build the heavy elements, e.g. $^{138}{\rm Ba}$.
#
# Now let's make an abundance-profile movie for the isotopes listed in **`species`** for cycles **`cycs`** so that we can see this happening in the model:

# %%
cycs=range(26100,27100,20)
species=['H-1','He-4','C-12','C-13','N-14','O-16']
pt.movie(cycs,plotstyle='plot',x_item='mass',
         y_items=species,logy=True,xlims=(0.5764,0.5775),
         ylims=(-10,0.),interval=100,legend=True,loc='lower right')
# Out:
# UnboundLocalErrorTraceback (most recent call last)
# <ipython-input-15-eb9efbac2a12> in <module>()
#       3 pt.movie(cycs,plotstyle='plot',x_item='mass',
#       4          y_items=species,logy=True,xlims=(0.5764,0.5775),
# ----> 5          ylims=(-10,0.),interval=100,legend=True,loc='lower right')
#
# /usr/local/lib/python2.7/dist-packages/nugridpy/data_plot.pyc in movie(self, cycles, plotstyle, movname, fps, **kwargs)
#    3844
#    3845         if plotstyle=='plot':
# -> 3846             return mov(cycles,plotstyle,movname,fps,data=data,**kwargs).ani
#    3847         else:
#    3848             return mov(cycles,plotstyle,movname,fps).ani
#
# UnboundLocalError: local variable 'data' referenced before assignment

# %% [markdown]
# # Issue 2

# %% [markdown]
# #### Animation
#
# Here's an iso_abund movie of the main s-process component being produced in the region where Ba-138 is shown to be produced in the abundance profile movie above:

# %%
cycs=range(26100,27100,20)
pt.movie(cycs,plotstyle='iso_abund',
         amass_range=[50,160],mass_range=[0.5768,0.5769])
# Out:
#  reading ['iso_massf', 'mass']...100%
# <div id='91f323a0-1026-422d-aa8f-e5ee44f0676d'></div>
# TypeErrorTraceback (most recent call last)
# <ipython-input-12-9fa6277f0dec> in <module>()
#       2 pt.movie(cycs,plotstyle='iso_abund',
#       3          amass_range=[50,160],mass_range=[0.5768,0.5769],plotaxis=[0, 80, 0, 60],
# ----> 4                 ilabel=False,imlabel=False,boxstable=False)
#
# /usr/local/lib/python2.7/dist-packages/nugridpy/data_plot.pyc in movie(self, cycles, plotstyle, movname, fps, **kwargs)
#    3846             return mov(cycles,plotstyle,movname,fps,data=data,**kwargs).ani
#    3847         else:
# -> 3848             return mov(cycles,plotstyle,movname,fps).ani
#    3849
#    3850     # From mesa_profile
#
# /usr/local/lib/python2.7/dist-packages/nugridpy/data_plot.pyc in __init__(self, cyc, style, movname, fps, **kwargs)
#    3707                     self.y_ditems=kwargs['y_items']
#    3708                     self.data=kwargs['data']
# -> 3709                 self._init_animation(animateFunc)
#    3710
#    3711             def _init_animation(self, animateFunc):
#
# /usr/local/lib/python2.7/dist-packages/nugridpy/data_plot.pyc in _init_animation(self, animateFunc)
#    3762                                       loc='best').draw_frame(False)
#    3763
# -> 3764                 self._animation(animateFunc)
#    3765
#    3766             def _animation(self, animateFunc):
#
# /usr/local/lib/python2.7/dist-packages/nugridpy/data_plot.pyc in _animation(self, animateFunc)
#    3771                     ims=[]
#    3772                     for i in arange(0,len(self.cyc)):
# -> 3773                         im=draw_frame(i,self)
#    3774                         ims.append(im)
#    3775                     self.ani = animation.ArtistAnimation(self.fig,ims,interval=50,
#
# /usr/local/lib/python2.7/dist-packages/nugridpy/data_plot.pyc in draw_frame(i, self)
#    3811                                              data_provided=True,thedata=data[i],
#    3812                                              verbose=False,drawfig=self.fig,drawax=self.ax,
# -> 3813                                              mov=True,**kwargs)
#    3814                     return artists
#    3815             if plotstyle == 'abu_chart':
#
# TypeError: iso_abund() got an unexpected keyword argument 'ilabel'

# %% [markdown]
# # Star_explore.ipynb widget does not work.

# %% [markdown]
# # Demos/Making_Movies.ipynb for making movies does not work

# %% [markdown]
# # Presolar_Grain_Workshop_2015

# %%
m2pp_out = mp.se(mass=2., Z=0.02, output='out')
# Out:
# nugrid_path = /data/nugrid_apod2
# closest set is set1.2 (Z = 0.02)
# closest mass is 2.0
# Searching files, please wait.......
# Reading preprocessor files
# File search complete.

# %%
# define cycles
cycs = range(27000,27500,20)
# define species to plot
species=['H-1','He-4','C-12','C-13','N-14','O-16','Fe-56','Zr-96','Mo-98','Ba-138']
# make the movie
m2pp_out.movie(cycs,plotstyle='plot',x_item='mass',
         y_items=species,logy=True,xlims=(0.57,0.585),
         ylims=(-10,0.),interval=100,legend=True,loc='lower right')
# Out:
# UnboundLocalErrorTraceback (most recent call last)
# <ipython-input-20-9f5163720f40> in <module>()
#       6 m2pp_out.movie(cycs,plotstyle='plot',x_item='mass',
#       7          y_items=species,logy=True,xlims=(0.57,0.585),
# ----> 8          ylims=(-10,0.),interval=100,legend=True,loc='lower right')
#
# /usr/local/lib/python2.7/dist-packages/nugridpy/data_plot.pyc in movie(self, cycles, plotstyle, movname, fps, **kwargs)
#    3844
#    3845         if plotstyle=='plot':
# -> 3846             return mov(cycles,plotstyle,movname,fps,data=data,**kwargs).ani
#    3847         else:
#    3848             return mov(cycles,plotstyle,movname,fps).ani
#
# UnboundLocalError: local variable 'data' referenced before assignment

# %%
# define axis
zrxiso = ['Zr-96','Zr-94']
zryiso = ['Zr-92','Zr-94']

fol2gdb = '/data/nugrid_vos/data/supplements/validation/grain_data/'
iniabufile = '/data/nugrid_vos/data/supplements/iniab2.0E-02GN93.ppn'

# import the class
from nugridpy import grain
# load an instance g that contains all grain data
g = grain.gdb(gdbdir=fol2gdb,iniabufile=iniabufile)

g.plot_isoratios(zrxiso,zryiso,iniabufile=iniabufile)
# Out:
# Reading in... this takes a little bit
# WARNING:
# This initial abundance file uses an element name that does
# not contain the mass number in the 3rd to 5th position.
# It is assumed that this is the proton and we will change
# the name to 'h   1' to be consistent with the notation used
# in iniab.dat files
# WARNING:
# This initial abundance file uses an element name that does
# not contain the mass number in the 3rd to 5th position.
# It is assumed that this is the proton and we will change
# the name to 'h   1' to be consistent with the notation used
# in iniab.dat files
# Presolar grains are cool!
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:913: UserWarning: text.fontsize is deprecated and replaced with font.size; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# <img src="data:image/png;base64,..." width="639.999990463257">
# ValueErrorTraceback (most recent call last)
# <ipython-input-23-7acdc8ccf1ec> in <module>()
#      11 g = grain.gdb(gdbdir=fol2gdb,iniabufile=iniabufile)
#      12
# ---> 13 g.plot_isoratios(zrxiso,zryiso,iniabufile=iniabufile)
#
# /usr/local/lib/python2.7/dist-packages/nugridpy/data_plot.pyc in plot_isoratios(self, xiso, yiso, fign, spec, deltax, deltay, logx, logy, title, legend, legloc, errbar, dcycle, addiso, co_toggle, cust_toggle, shift, weighting, zoneselect, iniabufile, plt_sparse, plt_symb, plt_col, plt_lt, plt_lw, alpha_dum, plt_massrange, plt_show, figsave)
#    1135                                 color=style[i][1],linestyle='',lw=2,markevery=plt_sparse,alpha=alpha_dum)
#    1136             pl.plot(xdata[i],ydata[i],style[i][0],c=style[i][1],mfc=style[i][2],ms=float(style[i][3]),
# -> 1137                     mew=float(style[i][4]),label=style[i][5],markevery=plt_sparse,linewidth=plt_lw,alpha=alpha_dum)
#    1138
#    1139         # plot text labels if necessary
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1404         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1405
# -> 1406         for line in self._get_lines(*args, **kwargs):
#    1407             self.add_line(line)
#    1408             lines.append(line)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
#     405                 return
#     406             if len(remaining) <= 3:
# --> 407                 for seg in self._plot_args(remaining, kwargs):
#     408                     yield seg
#     409                 return
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in _plot_args(self, tup, kwargs)
#     393         ncx, ncy = x.shape[1], y.shape[1]
#     394         for j in xrange(max(ncx, ncy)):
# --> 395             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     396             ret.append(seg)
#     397         return ret
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in _makeline(self, x, y, kw, kwargs)
#     300         default_dict = self._getdefaults(None, kw)
#     301         self._setdefaults(default_dict, kw)
# --> 302         seg = mlines.Line2D(x, y, **kw)
#     303         return seg
#     304
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     398         self.set_linestyle(linestyle)
#     399         self.set_drawstyle(drawstyle)
# --> 400         self.set_linewidth(linewidth)
#     401
#     402         self._color = None
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/lines.pyc in set_linewidth(self, w)
#    1043         ACCEPTS: float value in points
#    1044         """
# -> 1045         w = float(w)
#    1046
#    1047         if self._linewidth != w:
#
# ValueError: could not convert string to float:
